# %% [markdown]
# ## Notebook pour l'entraînement des modèles

# %% [markdown]
# ## Importation des bibliothèques

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
import pickle
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Préparation des données

# %%
# Set up paths
EXPORTS_BY_PRODUCT_TIME_SERIES = r'../data/processed/exports_by_product_time_series.csv'

# Load data
exports_by_product_time_series = pd.read_csv(EXPORTS_BY_PRODUCT_TIME_SERIES)

# %%
exports_by_product_time_series.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1940 entries, 0 to 1939
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   product  1940 non-null   object
#  1   year     1940 non-null   int64
#  2   value    1940 non-null   float64
#  3   share    1940 non-null   float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 60.8+ KB

# %% [markdown]
# ## Entraînement des modèles

# %%
# columns: product, year, value, share
product_list = exports_by_product_time_series['product'].unique()
product_store = {}

for product in product_list:
    # Get the data for the product
    df = exports_by_product_time_series[exports_by_product_time_series['product'] == product]
    # Reset the index
    df.reset_index(drop=True, inplace=True)
    # Store the dataframe
    product_store[product] = {'df': df, 'len': int(df.shape[0])}

# %%
print(product_store.keys())
print(product_store['Fertilisers'])
# Out:
# dict_keys(['Fertilisers', 'Vehicles other than railway or tramway rolling stock, and parts and accessories thereof', 'Electrical machinery and equipment and parts thereof; sound recorders and reproducers, television ...', 'Articles of apparel and clothing accessories, not knitted or crocheted', 'Inorganic chemicals; organic or inorganic compounds of precious metals, of rare-earth metals, ...', 'Edible fruit and nuts; peel of citrus fruit or melons', 'Edible vegetables and certain roots and tubers', 'Salt; sulphur; earths and stone; plastering materials, lime and cement', 'Fish and crustaceans, molluscs and other aquatic invertebrates', 'Aircraft, spacecraft, and parts thereof', 'Preparations of meat, of fish, of crustaceans, molluscs or other aquatic invertebrates, or ...', 'Articles of apparel and clothing accessories, knitted or crocheted', 'Nuclear reactors, boilers, machinery and mechanical appliances; parts thereof', 'Sugars and sugar confectionery', 'Mineral fuels, mineral oils and products of their distillation; bituminous substances; mineral ...', 'Animal, vegetable or microbial fats and oils and their cleavage products; prepared edible fats; ...', 'Ores, slag and ash', 'Footwear, gaiters and the like; parts of such articles', 'Plastics and articles thereof', 'Furniture; bedding, mattresses, mattress supports, cushions and similar stuffed furnishings; ...', 'Other made-up textile articles; sets; worn clothing and worn textile articles; rags', 'Residues and waste from the food industries; prepared animal fodder', 'Aluminium and articles thereof', 'Oil seeds and oleaginous fruits; miscellaneous grains, seeds and fruit; industrial or medicinal ...', 'Articles of iron or steel', 'Preparations of vegetables, fruit, nuts or other parts of plants', 'Copper and articles thereof', 'Other base metals; cermets; articles thereof', 'Pharmaceutical products', 'Rubber and articles thereof', 'Natural or cultured pearls, precious or semi-precious stones, precious metals, metals clad ...', 'Paper and paperboard; articles of paper pulp, of paper or of paperboard', 'Miscellaneous edible preparations', 'Iron and steel', 'Essential oils and resinoids; perfumery, cosmetic or toilet preparations', "Preparations of cereals, flour, starch or milk; pastrycooks' products", 'Ceramic products', 'Articles of leather; saddlery and harness; travel goods, handbags and similar containers; articles ...', 'Glass and glassware', 'Products of animal origin, not elsewhere specified or included', 'Tobacco and manufactured tobacco substitutes; products, whether or not containing nicotine, ...', 'Lac; gums, resins and other vegetable saps and extracts', 'Coffee, tea, maté and spices', 'Miscellaneous manufactured articles', "Dairy produce; birds' eggs; natural honey; edible products of animal origin, not elsewhere ...", 'Wood and articles of wood; wood charcoal', 'Optical, photographic, cinematographic, measuring, checking, precision, medical or surgical ...', 'Man-made staple fibres', 'Articles of stone, plaster, cement, asbestos, mica or similar materials', 'Cotton', 'Raw hides and skins (other than furskins) and leather', 'Miscellaneous articles of base metal', 'Beverages, spirits and vinegar', 'Carpets and other textile floor coverings', 'Tanning or dyeing extracts; tannins and their derivatives; dyes, pigments and other colouring ...', 'Live trees and other plants; bulbs, roots and the like; cut flowers and ornamental foliage', 'Special woven fabrics; tufted textile fabrics; lace; tapestries; trimmings; embroidery', 'Man-made filaments; strip and the like of man-made textile materials', 'Cork and articles of cork', 'Knitted or crocheted fabrics', 'Miscellaneous chemical products', 'Soap, organic surface-active agents, washing preparations, lubricating preparations, artificial ...', 'Manufactures of straw, of esparto or of other plaiting materials; basketware and wickerwork', 'Organic chemicals', 'Live animals', 'Wadding, felt and nonwovens; special yarns; t ...
# {'df':         product  year      value     share
# 0   Fertilisers  2003   0.234691  1.218663
# 1   Fertilisers  2004   0.329715  1.264092
# 2   Fertilisers  2005   0.350431  1.112663
# 3   Fertilisers  2006   0.492576  1.195949
# 4   Fertilisers  2007   1.038486  1.775165
# 5   Fertilisers  2008   1.890918  2.271096
# 6   Fertilisers  2009   0.753488  1.491236
# 7   Fertilisers  2010   2.128797  2.937384
# 8   Fertilisers  2011   3.331850  3.664244
# 9   Fertilisers  2012   3.489096  3.880031
# 10  Fertilisers  2013   2.705785  2.926027
# 11  Fertilisers  2014   2.922718  2.884384
# 12  Fertilisers  2015   2.622980  2.804884
# 13  Fertilisers  2016   3.037497  3.141814
# 14  Fertilisers  2017   3.749123  3.421958
# 15  Fertilisers  2018   4.684891  3.702102
# 16  Fertilisers  2019   4.281744  3.338672
# 17  Fertilisers  2020   5.030508  4.235889
# 18  Fertilisers  2021   8.737062  5.523037
# 19  Fertilisers  2022  11.919758  6.511113, 'len': 20}

# %%
print('Length of product store:', len(product_store))
# Out:
# Length of product store: 97

# %%
# Split the data into training and testing sets
for product in product_store:
    df = product_store[product]['df']
    df_train = df[df['year'] < 2020]
    df_test = df[df['year'] >= 2020]
    product_store[product]['train'] = df_train
    product_store[product]['test'] = df_test

# %%
# Calculate the root mean squared error
def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

# %%
# Forecast the product
def forecast_product(product, order=(5,1,0)):
    # Extract training and testing data
    df_train = product_store[product]['train']
    df_test = product_store[product]['test']
    
    # Fit the ARIMA model
    model = ARIMA(df_train['value'], order=order)
    model_fit = model.fit()
    
    # Forecast the test set
    forecast = model_fit.forecast(steps=len(df_test))
    
    # Get the actual value from the test set
    actual = df_test['value'].values
    
    # Calculate the error
    error = rmse(actual, forecast.values)
    
    return forecast, actual, error

# %%
# Test the function
results = {}
for product in product_store:
    print('Forecasting ', product)
    forecast, actual, error = forecast_product(product)
    results[product] = {'forecast': forecast, 'actual': actual, 'error': error}
# Out:
# Forecasting  Fertilisers
# Forecasting  Vehicles other than railway or tramway rolling stock, and parts and accessories thereof
# Forecasting  Electrical machinery and equipment and parts thereof; sound recorders and reproducers, television ...
# Forecasting  Articles of apparel and clothing accessories, not knitted or crocheted
# Forecasting  Inorganic chemicals; organic or inorganic compounds of precious metals, of rare-earth metals, ...
# Forecasting  Edible fruit and nuts; peel of citrus fruit or melons
# Forecasting  Edible vegetables and certain roots and tubers
# Forecasting  Salt; sulphur; earths and stone; plastering materials, lime and cement
# Forecasting  Fish and crustaceans, molluscs and other aquatic invertebrates
# Forecasting  Aircraft, spacecraft, and parts thereof
# Forecasting  Preparations of meat, of fish, of crustaceans, molluscs or other aquatic invertebrates, or ...
# Forecasting  Articles of apparel and clothing accessories, knitted or crocheted
# Forecasting  Nuclear reactors, boilers, machinery and mechanical appliances; parts thereof
# Forecasting  Sugars and sugar confectionery
# Forecasting  Mineral fuels, mineral oils and products of their distillation; bituminous substances; mineral ...
# Forecasting  Animal, vegetable or microbial fats and oils and their cleavage products; prepared edible fats; ...
# Forecasting  Ores, slag and ash
# Forecasting  Footwear, gaiters and the like; parts of such articles
# Forecasting  Plastics and articles thereof
# Forecasting  Furniture; bedding, mattresses, mattress supports, cushions and similar stuffed furnishings; ...
# Forecasting  Other made-up textile articles; sets; worn clothing and worn textile articles; rags
# Forecasting  Residues and waste from the food industries; prepared animal fodder
# Forecasting  Aluminium and articles thereof
# Forecasting  Oil seeds and oleaginous fruits; miscellaneous grains, seeds and fruit; industrial or medicinal ...
# Forecasting  Articles of iron or steel
# Forecasting  Preparations of vegetables, fruit, nuts or other parts of plants
# Forecasting  Copper and articles thereof
# Forecasting  Other base metals; cermets; articles thereof
# Forecasting  Pharmaceutical products
# Forecasting  Rubber and articles thereof
# Forecasting  Natural or cultured pearls, precious or semi-precious stones, precious metals, metals clad ...
# Forecasting  Paper and paperboard; articles of paper pulp, of paper or of paperboard
# Forecasting  Miscellaneous edible preparations
# Forecasting  Iron and steel
# Forecasting  Essential oils and resinoids; perfumery, cosmetic or toilet preparations
# Forecasting  Preparations of cereals, flour, starch or milk; pastrycooks' products
# Forecasting  Ceramic products
# Forecasting  Articles of leather; saddlery and harness; travel goods, handbags and similar containers; articles ...
# Forecasting  Glass and glassware
# Forecasting  Products of animal origin, not elsewhere specified or included
# Forecasting  Tobacco and manufactured tobacco substitutes; products, whether or not containing nicotine, ...
# Forecasting  Lac; gums, resins and other vegetable saps and extracts
# Forecasting  Coffee, tea, maté and spices
# Forecasting  Miscellaneous manufactured articles
# Forecasting  Dairy produce; birds' eggs; natural honey; edible products of animal origin, not elsewhere ...
# Forecasting  Wood and articles of wood; wood charcoal
# Forecasting  Optical, photographic, cinematographic, measuring, checking, precision, medical or surgical ...
# Forecasting  Man-made staple fibres
# Forecasting  Articles of stone, plaster, cement, asbestos, mica or similar materials
# Forecasting  Cotton
# Forecasting  Raw hides and skins (other than furskins) and leather
# Forecasting  Miscellaneous articles of base metal
# Forecasting  Beverages, spirits and vinegar
# Forecasting  Carpets and other textile floor coverings
# Forecasting  Tanning or dyeing extracts; tannins and their derivatives; dyes, pigments and other colouring ...
# Forecasting  Live trees and other plants; bulbs, roots and the like; cut flowers and ornamental foliage
# Forecasting  Special woven fabrics; tufted textile fabrics; lace; tapestries; trimmings; embroidery
# Forecasting  Man-made filaments; strip and the like of man-made textile materials
# Forecasting  Cork and articles of cork
# Forecasting  Knitted or crocheted fabrics
# Forecasting  Miscellaneous chemical products
# Forecasting  Soap, organic surface-active agents, washing preparations, lubricating preparations, artificial ...
# Forecasting  Manufactures of straw, of esparto or of other plaiting materials; basketware and wickerwork
# Forecasting  Organic chemicals
# Forecasting  Live animals
# Forecasting  Wadding, felt and nonwovens; special yarns; twine, cordage, ropes and cables and articles thereof
# Forecasting  Printed books, newspapers, pictures and other products of the printing industry; manuscripts, ...
# Forecasting  Toys, games and sports requisites; parts and accessories thereof
# Forecasting  Headgear and parts thereof
# Forecasting  Impregnated, coated, covered or laminated textile fabrics; textile articles of a kind suitable ...
# Forecasting  Works of art, collectors' pieces and antiques
# Forecasting  Pulp of wood or of other fibrous cellulosic material; recovered (waste and scrap) paper or ...
# Forecasting  Ships, boats and floating structures
# Forecasting  Tools, implements, cutlery, spoons and forks, of base metal; parts thereof of base metal
# Forecasting  Products of the milling industry; malt; starches; inulin; wheat gluten
# Forecasting  Zinc and articles thereof
# Forecasting  Cocoa and cocoa preparations
# Forecasting  Wool, fine or coarse animal hair; horsehair yarn and woven fabric
# Forecasting  Nickel and articles thereof
# Forecasting  Albuminoidal substances; modified starches; glues; enzymes
# Forecasting  Meat and edible meat offal
# Forecasting  Clocks and watches and parts thereof
# Forecasting  Explosives; pyrotechnic products; matches; pyrophoric alloys; certain combustible preparations
# Forecasting  Railway or tramway locomotives, rolling stock and parts thereof; railway or tramway track fixtures ...
# Forecasting  Other vegetable textile fibres; paper yarn and woven fabrics of paper yarn
# Forecasting  Vegetable plaiting materials; vegetable products not elsewhere specified or included
# Forecasting  Cereals
# Forecasting  Tin and articles thereof
# Forecasting  Prepared feathers and down and articles made of feathers or of down; artificial flowers; articles ...
# Forecasting  Umbrellas, sun umbrellas, walking sticks, seat-sticks, whips, riding-crops and parts thereof
# Forecasting  Furskins and artificial fur; manufactures thereof
# Forecasting  Photographic or cinematographic goods
# Forecasting  Musical instruments; parts and accessories of such articles
# Forecasting  Silk
# Forecasting  Lead and articles thereof
# Forecasting  Arms and ammunition; parts and accessories thereof
# Forecasting  Commodities not elsewhere specified

# %%
# Calculate the overall error
overall_error = 0
for product in results:
    overall_error += results[product]['error']
overall_error /= len(results)

# %%
for index, product in enumerate(results):
    print("Product: ", product)
    print("RMSE: ", results[product]['error'])
    print("---------------------------------------")
print('Overall RMSE: ', overall_error)
# Out:
# Product:  Fertilisers
# RMSE:  5.025637578185864
# ---------------------------------------
# Product:  Vehicles other than railway or tramway rolling stock, and parts and accessories thereof
# RMSE:  2.4427141689431395
# ---------------------------------------
# Product:  Electrical machinery and equipment and parts thereof; sound recorders and reproducers, television ...
# RMSE:  0.8067556324836216
# ---------------------------------------
# Product:  Articles of apparel and clothing accessories, not knitted or crocheted
# RMSE:  0.6497241230823675
# ---------------------------------------
# Product:  Inorganic chemicals; organic or inorganic compounds of precious metals, of rare-earth metals, ...
# RMSE:  1.2224581772836463
# ---------------------------------------
# Product:  Edible fruit and nuts; peel of citrus fruit or melons
# RMSE:  0.0352126327147356
# ---------------------------------------
# Product:  Edible vegetables and certain roots and tubers
# RMSE:  0.30577503938808187
# ---------------------------------------
# Product:  Salt; sulphur; earths and stone; plastering materials, lime and cement
# RMSE:  0.5887568288752271
# ---------------------------------------
# Product:  Fish and crustaceans, molluscs and other aquatic invertebrates
# RMSE:  0.6704332734651817
# ---------------------------------------
# Product:  Aircraft, spacecraft, and parts thereof
# RMSE:  0.47366540497476245
# ---------------------------------------
# Product:  Preparations of meat, of fish, of crustaceans, molluscs or other aquatic invertebrates, or ...
# RMSE:  0.0264433580958331
# ---------------------------------------
# Product:  Articles of apparel and clothing accessories, knitted or crocheted
# RMSE:  0.17024300794912509
# ---------------------------------------
# Product:  Nuclear reactors, boilers, machinery and mechanical appliances; parts thereof
# RMSE:  0.07327282006353499
# ---------------------------------------
# Product:  Sugars and sugar confectionery
# RMSE:  0.1364808180952782
# ---------------------------------------
# Product:  Mineral fuels, mineral oils and products of their distillation; bituminous substances; mineral ...
# RMSE:  0.37130761450656335
# ---------------------------------------
# Product:  Animal, vegetable or microbial fats and oils and their cleavage products; prepared edible fats; ...
# RMSE:  0.1455659921144306
# ---------------------------------------
# Product:  Ores, slag and ash
# RMSE:  0.06656621060024319
# ---------------------------------------
# Product:  Footwear, gaiters and the like; parts of such articles
# RMSE:  0.0731766197663991
# ---------------------------------------
# Product:  Plastics and articles thereof
# RMSE:  0.031230434830682555
# ---------------------------------------
# Product:  Furniture; bedding, mattresses, mattress supports, cushions and similar stuffed furnishings; ...
# RMSE:  0.13855996742950402
# ---------------------------------------
# Product:  Other made-up textile articles; sets; worn clothing and worn textile articles; rags
# RMSE:  0.06298812205837771
# ---------------------------------------
# Product:  Residues and waste from the food industries; prepared animal fodder
# RMSE:  0.1123223524306585
# ---------------------------------------
# Product:  Aluminium and articles thereof
# RMSE:  0.1325488290180125
# ---------------------------------------
# Product:  Oil seeds and oleaginous fruits; miscellaneous grains, seeds and fruit; industrial or medicinal ...
# RMSE:  0.13144828165789915
# ---------------------------------------
# Product:  Articles of iron or steel
# RMSE:  0.09589840117420274
# ---------------------------------------
# Product:  Preparations of vegetables, fruit, nuts or other parts of plants
# RMSE:  0.04927832999751129
# ---------------------------------------
# Product:  Copper and articles thereof
# RMSE:  0.10967244164910163
# ---------------------------------------
# Product:  Other base metals; cermets; articles thereof
# RMSE:  0.027980139984150155
# ---------------------------------------
# Product:  Pharmaceutical products
# RMSE:  0.020692285190607188
# ---------------------------------------
# Product:  Rubber and articles thereof
# RMSE:  0.03717926419914096
# ---------------------------------------
# Product:  Natural or cultured pearls, precious or semi-precious stones, precious metals, metals clad ...
# RMSE:  0.08185856872613073
# ---------------------------------------
# Product:  Paper and paperboard; articles of paper pulp, of paper or of paperboard
# RMSE:  0.021447210448986433
# ---------------------------------------
# Product:  Miscellaneous edible preparations
# RMSE:  0.039824645963659165
# ---------------------------------------
# Product:  Iron and steel
# RMSE:  0.0791482423342611
# ---------------------------------------
# Product:  Essential oils and resinoids; perfumery, cosmetic or toilet preparations
# RMSE:  0.05714261631725795
# ---------------------------------------
# Product:  Preparations of cereals, flour, starch or milk; pastrycooks' products
# RMSE:  0.04042195549434632
# ---------------------------------------
# Product:  Ceramic products
# RMSE:  0.04071802914190108
# ---------------------------------------
# Product:  Articles of leather; saddlery and harness; travel goods, handbags and similar containers; articles ...
# RMSE:  0.017720037538412253
# ---------------------------------------
# Product:  Glass and glassware
# RMSE:  0.051583835448318856
# ---------------------------------------
# Product:  Products of animal origin, not elsewhere specified or included
# RMSE:  0.023815588690250078
# ---------------------------------------
# Product:  Tobacco and manufactured tobacco substitutes; products, whether or not containing nicotine, ...
# RMSE:  0.06643067794623132
# ---------------------------------------
# Product:  Lac; gums, resins and other vegetable saps and extracts
# RMSE:  0.012861479555961591
# ---------------------------------------
# Product:  Coffee, tea, maté and spices
# RMSE:  0.0044371097994876105
# ---------------------------------------
# Product:  Miscellaneous manufactured articles
# RMSE:  0.06374234978645617
# ---------------------------------------
# Product:  Dairy produce; birds' eggs; natural honey; edible products of animal origin, not elsewhere ...
# RMSE:  0.012521898093654244
# ---------------------------------------
# Product:  Wood and articles of wood; wood charcoal
# RMSE:  0.02660858548669756
# ---------------------------------------
# Product:  Optical, photographic, cinematographic, measuring, checking, precision, medical or surgical ...
# RMSE:  0.019798443883059597
# ---------------------------------------
# Product:  Man-made staple fibres
# RMSE:  0.02456397397693988
# ---------------------------------------
# Product:  Articles of stone, plaster, cement, asbestos, mica or similar materials
# RMSE:  0.012265256782117078
# ---------------------------------------
# Product:  Cotton
# RMSE:  0.013028826463614042
# ---------------------------------------
# Product:  Raw hides and skins (other than furskins) and leather
# RMSE:  0.026698290515591853
# ---------------------------------------
# Product:  Miscellaneous articles of base metal
# RMSE:  0.025939246886324478
# ---------------------------------------
# Product:  Beverages, spirits and vinegar
# RMSE:  0.005170091599482877
# ---------------------------------------
# Product:  Carpets and other textile floor coverings
# RMSE:  0.006570700623664604
# ---------------------------------------
# Product:  Tanning or dyeing extracts; tannins and their derivatives; dyes, pigments and other colouring ...
# RMSE:  0.006344497071852771
# ---------------------------------------
# Product:  Live trees and other plants; bulbs, roots and the like; cut flowers and ornamental foliage
# RMSE:  0.015101112355378067
# ---------------------------------------
# Product:  Special woven fabrics; tufted textile fabrics; lace; tapestries; trimmings; embroidery
# RMSE:  0.013806482158163637
# ---------------------------------------
# Product:  Man-made filaments; strip and the like of man-made textile materials
# RMSE:  0.01027440433915594
# ---------------------------------------
# Product:  Cork and articles of cork
# RMSE:  0.018885609143252532
# ---------------------------------------
# Product:  Knitted or crocheted fabrics
# RMSE:  0.007408790465741674
# ---------------------------------------
# Product:  Miscellaneous chemical products
# RMSE:  0.015372171571760122
# ---------------------------------------
# Product:  Soap, organic surface-active agents, washing preparations, lubricating preparations, artificial ...
# RMSE:  0.004334266210866032
# ---------------------------------------
# Product:  Manufactures of straw, of esparto or of other plaiting materials; basketware and wickerwork
# RMSE:  0.00820328656020732
# ---------------------------------------
# Product:  Organic chemicals
# RMSE:  0.007040930506127962
# ---------------------------------------
# Product:  Live animals
# RMSE:  0.011632744692608875
# ---------------------------------------
# Product:  Wadding, felt and nonwovens; special yarns; twine, cordage, ropes and cables and articles thereof
# RMSE:  0.0039486643031054714
# ---------------------------------------
# Product:  Printed books, newspapers, pictures and other products of the printing industry; manuscripts, ...
# RMSE:  0.021131605517988993
# ---------------------------------------
# Product:  Toys, games and sports requisites; parts and accessories thereof
# RMSE:  0.009302784574875447
# ---------------------------------------
# Product:  Headgear and parts thereof
# RMSE:  0.0037290976269084963
# ---------------------------------------
# Product:  Impregnated, coated, covered or laminated textile fabrics; textile articles of a kind suitable ...
# RMSE:  0.004742828225574691
# ---------------------------------------
# Product:  Works of art, collectors' pieces and antiques
# RMSE:  0.009389960615378171
# ---------------------------------------
# Product:  Pulp of wood or of other fibrous cellulosic material; recovered (waste and scrap) paper or ...
# RMSE:  0.00715497632013216
# ---------------------------------------
# Product:  Ships, boats and floating structures
# RMSE:  0.0022673435351449832
# ---------------------------------------
# Product:  Tools, implements, cutlery, spoons and forks, of base metal; parts thereof of base metal
# RMSE:  0.007608885971726304
# ---------------------------------------
# Product:  Products of the milling industry; malt; starches; inulin; wheat gluten
# RMSE:  0.024310371270643873
# ---------------------------------------
# Product:  Zinc and articles thereof
# RMSE:  0.0035615050586544493
# ---------------------------------------
# Product:  Cocoa and cocoa preparations
# RMSE:  0.0004680933283886503
# ---------------------------------------
# Product:  Wool, fine or coarse animal hair; horsehair yarn and woven fabric
# RMSE:  0.006104339249457799
# ---------------------------------------
# Product:  Nickel and articles thereof
# RMSE:  0.0031553836794348685
# ---------------------------------------
# Product:  Albuminoidal substances; modified starches; glues; enzymes
# RMSE:  0.0011211496410076056
# ---------------------------------------
# Product:  Meat and edible meat offal
# RMSE:  0.0009244216846384984
# ---------------------------------------
# Product:  Clocks and watches and parts thereof
# RMSE:  0.0006701888728229752
# ---------------------------------------
# Product:  Explosives; pyrotechnic products; matches; pyrophoric alloys; certain combustible preparations
# RMSE:  0.0029880344812774364
# ---------------------------------------
# Product:  Railway or tramway locomotives, rolling stock and parts thereof; railway or tramway track fixtures ...
# RMSE:  0.003544121982841968
# ---------------------------------------
# Product:  Other vegetable textile fibres; paper yarn and woven fabrics of paper yarn
# RMSE:  0.00198664840608671
# ---------------------------------------
# Product:  Vegetable plaiting materials; vegetable products not elsewhere specified or included
# RMSE:  4.6828757256043766e-05
# ---------------------------------------
# Product:  Cereals
# RMSE:  0.0017930948553140855
# ---------------------------------------
# Product:  Tin and articles thereof
# RMSE:  0.0004398761203726302
# ---------------------------------------
# Product:  Prepared feathers and down and articles made of feathers or of down; artificial flowers; articles ...
# RMSE:  0.0003993811549442104
# ---------------------------------------
# Product:  Umbrellas, sun umbrellas, walking sticks, seat-sticks, whips, riding-crops and parts thereof
# RMSE:  0.00011423822295304578
# ---------------------------------------
# Product:  Furskins and artificial fur; manufactures thereof
# RMSE:  0.0013939839209366135
# ---------------------------------------
# Product:  Photographic or cinematographic goods
# RMSE:  0.00017189357980984413
# ---------------------------------------
# Product:  Musical instruments; parts and accessories of such articles
# RMSE:  0.00010611492723249804
# ---------------------------------------
# Product:  Silk
# RMSE:  7.850344999384713e-05
# ---------------------------------------
# Product:  Lead and articles thereof
# RMSE:  0.004301022607288411
# ---------------------------------------
# Product:  Arms and ammunition; parts and accessories thereof
# RMSE:  0.00048781061985015046
# ---------------------------------------
# Product:  Commodities not elsewhere specified
# RMSE:  0.0
# ---------------------------------------
# Overall RMSE:  0.1572593119520396

# %%
# Save the model
with open('../models/arima_model.pkl', 'wb') as f:
    pickle.dump(results, f)
